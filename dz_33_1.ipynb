# %% [markdown]
# #### Pavlo Yatluk
# #### dz_33

# %% [markdown]
# ### ЗАВДАННЯ

# %% [markdown]
# #### 1. Створіть xlsx-документ, що містить дані про марки автомобілів, їхню вартість, споживання палива, максимальну швидкість та вантажопідйомність. Кількість записів у документі - 20.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import openpyxl

car_compare = pd.read_excel("C:\projects sta\pythonProject\Cars_dz_33.xlsx")
car_compare
# Out:
#                        Car   Cost   Oil  Speed  Load_capacity      Type
# 0             Honda Accord  32990   9.1    210            416     Sport
# 1               Honda CR-V  27000   9.8    188            520     Sedan
# 2                   BMW X6  50000  10.1    240            600     Sport
# 3      Bentley Continental  75000  14.5    330            358     Sport
# 4        Volkswagen Amarok  30000   7.6    179            835  Families
# 5                Volvo S60  35000   4.1    190            415     Sedan
# 6            Infiniti JX35  30000  10.7    190            534     Sedan
# 7   Land Rover Range Rover  60000   7.5    210            840     Sport
# 8                 Lexus CT  55000   4.1    180            360  Families
# 9                  Mazda 3  24000   7.8    174            460  Families
# 10   Mercedes-Benz A-Class  50000   5.8    202            565     Sport
# 11         Mini Countryman  25000   7.9    223            510     Sport
# ...

# %% [markdown]
# #### 2. Візуалізуйте залежності: споживання палива від вартості - лінійною діаграмою; споживання палива від швидкості - точковим графіком; вантажопідйомності від швидкості - точковим графіком.

# %%
sns.set_style("darkgrid")
sns.lineplot(data = car_compare, x = "Oil", y = "Cost")
# Out:
# <AxesSubplot: xlabel='Oil', ylabel='Cost'>

# %%
sns.set_style("darkgrid")
sns.scatterplot(data = car_compare, x = "Oil", y = "Speed")
# Out:
# <AxesSubplot: xlabel='Oil', ylabel='Speed'>

# %%
sns.set_style("darkgrid")
sns.scatterplot(data = car_compare, x = "Load_capacity", y = "Speed")
# Out:
# <AxesSubplot: xlabel='Load_capacity', ylabel='Speed'>

# %% [markdown]
# #### 3. Побудуйте гістограму для розділення автомобілів на 5 груп за швидкістю.

# %%
sns.histplot(car_compare, x="Speed", bins=5)
# Out:
# <AxesSubplot: xlabel='Speed', ylabel='Count'>

# %% [markdown]
# #### 4. Побудуйте коробковий графік для відображення швидкостей різних марок.

# %%
sns.boxplot(car_compare, x = "Speed", y = "Type")
# Out:
# <AxesSubplot: xlabel='Speed', ylabel='Type'>

# %% [markdown]
# #### 5. Побудуйте парний графік для відображення залежностей величин датасету.

# %%
sns.pairplot(car_compare)
